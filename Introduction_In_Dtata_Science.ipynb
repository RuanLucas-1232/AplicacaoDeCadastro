# %% [markdown]
# <a href="https://colab.research.google.com/github/RuanLucas-1232/AplicacaoDeCadastro/blob/main/Introduction_In_Dtata_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

casas = pd.read_csv("/content/sample_data/california_housing_test.csv")
casas
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
casas["longitude"]
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
casas["longitude"].max()
# Out:
# -114.49

# %%
casas["longitude"].min()
# -114 é maior que -124, mas +114 é menor que +124.
# Se quero  saber qual é o valor negativo, em numeros, o maior uso o max(), porém se quero o menor uso max().
# Out:
# -124.18

# %%
casas.head(10)
# Esse script me dá os 10 primeros números do arquivo.
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
casas["latitude"].head(10)
# Dá os 10 primeiros valores de latitude.
# Out:
# 0    37.37
# 1    34.26
# 2    33.78
# 3    33.82
# 4    36.33
# 5    36.51
# 6    38.63
# 7    35.48
# 8    38.40
# 9    34.08
# Name: latitude, dtype: float64

# %%
casas_california = casas.to_excel("casas_california.xlsx", sheet_name= "casas_na_california", index =False)
print(casas_california)
# Converte o csv em planilha do exel, mas sem os índices da tabela  que é criado pelo python.
# Out:
# None

# %%
casas_california_sem_indice = casas.to_excel("casas_california_sem_indice.xlsx", sheet_name= "casas_na_california")
print(casas_california_sem_indice)
# Converte o csv em planilha do exel, mas com os índices da tabela  que é criado pelo python.
# Out:
# None

# %%
casas_com_indice = pd.read_excel("/content/casas_california.xlsx")
casas_com_indice
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27         3885             661
# 1       -118.30     34.26                  43         1510             310
# 2       -117.81     33.78                  27         3589             507
# 3       -118.36     33.82                  28           67              15
# 4       -119.67     36.33                  19         1241             244
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                  23         1450             642
# 2996    -118.14     34.06                  27         5257            1082
# 2997    -119.70     36.30                  10          956             201
# 2998    -117.12     34.10                  40           96              14
# 2999    -119.63     34.42                  42         1765             263
#
#       population  households  median_income  median_house_value
# ...

# %%
casas_sem_indice = pd.read_excel("/content/casas_california_sem_indice.xlsx")
casas_sem_indice
# Out:
#       Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0              0    -122.05     37.37                  27         3885
# 1              1    -118.30     34.26                  43         1510
# 2              2    -117.81     33.78                  27         3589
# 3              3    -118.36     33.82                  28           67
# 4              4    -119.67     36.33                  19         1241
# ...          ...        ...       ...                 ...          ...
# 2995        2995    -119.86     34.42                  23         1450
# 2996        2996    -118.14     34.06                  27         5257
# 2997        2997    -119.70     36.30                  10          956
# 2998        2998    -117.12     34.10                  40           96
# 2999        2999    -119.63     34.42                  42         1765
#
#       total_bedrooms  population  households  median_income  \
# ...
